# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
#from google.colab import files
#uploaded = files.upload('../../DATA/Employee-attrition.csv')
#import io
df = pd.read_csv('../../DATA/Employee-attrition.csv')

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Types of Data Frame

# %%
# A:

df.dtypes.count
# Out:
# <bound method Series.count of EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object>

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info
# Out:
# <bound method DataFrame.info of        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %%
df.diff
# Out:
# <bound method DataFrame.diff of        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A:
df['job_title']
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A:
df['job_title'].count
# Out:
# <bound method Series.count of 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object>

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
def row_count(column_name):
    number_of_rows = len(df[column_name])
    return number_of_rows

print(row_count('job_title'))
print(row_count('EmployeeID'))
# Out:
# 49653
# 49653

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:
df
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# ...           ...              ...           ...              ...
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 0                1/1/1900   52                 17    Vancouver
# ...

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
df.iloc[2]
# Out:
# EmployeeID                        1318
# recorddate_key         12/31/2008 0:00
# birthdate_key                 1/3/1954
# orighiredate_key             8/28/1989
# terminationdate_key           1/1/1900
# age                                 54
# length_of_service                   19
# city_name                    Vancouver
# department_name              Executive
# job_title                          CEO
# store_name                          35
# gender_short                         M
# gender_full                       Male
# termreason_desc         Not Applicable
# termtype_desc           Not Applicable
# STATUS_YEAR                       2008
# STATUS                          ACTIVE
# BUSINESS_UNIT               HEADOFFICE
# Name: 2, dtype: object

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
df.sort_index(ascending=0)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 49652        8321   12/1/2014 0:00    11/28/1994       11/24/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
# 49650        8279   12/1/2015 0:00     7/18/1994        9/15/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49648        8258   12/1/2015 0:00     5/28/1994        8/19/2013
# ...           ...              ...           ...              ...
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49652          12/30/2014   20                  1  Grand Forks
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
df.sort_values(by = ['age'], ascending = [False])
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 48530        2800    6/1/2007 0:00      6/3/1942        12/9/1993
# 48498        2674    2/1/2007 0:00     2/11/1942        8/19/1993
# 48486        2598   11/1/2006 0:00    11/22/1941        5/30/1993
# 48487        2599   11/1/2006 0:00    11/25/1941         6/2/1993
# 48488        2608   12/1/2006 0:00     12/1/1941         6/8/1993
# ...           ...              ...           ...              ...
# 48010        8283  12/31/2013 0:00     8/11/1994        9/27/2013
# 47839        8222  12/31/2013 0:00      2/1/1994        6/18/2013
# 47836        8221  12/31/2013 0:00     1/28/1994        6/16/2013
# 48013        8284  12/31/2013 0:00     8/10/1994        9/27/2013
# 48071        8304  12/31/2013 0:00     10/7/1994       10/27/2013
#
#       terminationdate_key  age  length_of_service        city_name  \
# 48530            6/3/2007   65                 13    Prince George
# ...

# %%
df.sort_values(by = ['length_of_service'], ascending = [False])
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 109          1331  12/31/2015 0:00     1/28/1965        9/10/1989
# 9            1318  12/31/2015 0:00      1/3/1954        8/28/1989
# 99           1330  12/31/2015 0:00     1/25/1967         9/9/1989
# 49           1322  12/31/2015 0:00      1/9/1958        8/31/1989
# 29           1320  12/31/2015 0:00      1/2/1955        8/28/1989
# ...           ...              ...           ...              ...
# 47732        8179  12/31/2013 0:00     9/11/1993         4/4/2013
# 44927        7499  12/31/2010 0:00     7/26/1988        7/19/2010
# 47734        8180  12/31/2013 0:00     9/16/1993         4/6/2013
# 47735        8182  12/31/2013 0:00     9/27/1993        4/12/2013
# 45801        7669  12/31/2011 0:00    10/19/1989        3/14/2011
#
#       terminationdate_key  age  length_of_service     city_name  \
# 109              1/1/1900   50                 26       Nanaimo
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:
df.sample()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 25215        5191  12/31/2014 0:00      2/5/1970       10/17/2000
#
#       terminationdate_key  age  length_of_service city_name department_name  \
# 25215            1/1/1900   44                 14   Nanaimo          Bakery
#
#       job_title  store_name gender_short gender_full termreason_desc  \
# 25215     Baker          18            F      Female  Not Applicable
#
#         termtype_desc  STATUS_YEAR  STATUS BUSINESS_UNIT
# 25215  Not Applicable         2014  ACTIVE        STORES

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:
df.loc[df['job_title'] == 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
grouped = df.groupby('age')

for age, group in grouped:
    print(age)
    print(group)
# Out:
# 19
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 47492        8088  12/31/2012 0:00      1/1/1993       11/21/2012
# 47496        8089  12/31/2012 0:00      1/6/1993       11/23/2012
# 47500        8090  12/31/2012 0:00      1/6/1993       11/23/2012
# 47504        8091  12/31/2012 0:00      1/6/1993       11/23/2012
# 47508        8092  12/31/2012 0:00     1/12/1993       11/26/2012
# ...           ...              ...           ...              ...
# 49636        8181    7/1/2013 0:00     9/26/1993        4/12/2013
# 49645        8223   10/1/2013 0:00     2/11/1994        6/24/2013
# 49646        8226    9/1/2013 0:00     2/16/1994        6/26/2013
# 49649        8264    8/1/2013 0:00     6/13/1994        8/27/2013
# 49651        8296   12/1/2013 0:00      9/2/1994        10/9/2013
#
#       terminationdate_key  age  length_of_service        city_name  \
# 47492            1/1/1900   19                  0  New Westminster
# ...

# %% [markdown]
# # 5. Visualization
#
# #### 5.A Plot Histogram of Age

# %%
# A:
print((len(df['age']))/1000)
plt.hist(df['age'], bins=50)
# Out:
# 49.653
# (array([ 158.,  408.,  703.,  815.,  960., 1111., 1197., 1210., 1235.,
#         1225., 1227., 1212.,    0., 1146., 1153., 1164., 1188., 1189.,
#         1176., 1149., 1156., 1142., 1130., 1135.,    0., 1152., 1150.,
#         1157., 1141., 1161., 1173., 1180., 1196., 1218., 1207., 1188.,
#         1188.,    0., 1159., 1168., 1154., 1130., 1130., 1128., 1109.,
#          757.,  712.,  667.,  646.,  593.]),
#  array([19.  , 19.92, 20.84, 21.76, 22.68, 23.6 , 24.52, 25.44, 26.36,
#         27.28, 28.2 , 29.12, 30.04, 30.96, 31.88, 32.8 , 33.72, 34.64,
#         35.56, 36.48, 37.4 , 38.32, 39.24, 40.16, 41.08, 42.  , 42.92,
#         43.84, 44.76, 45.68, 46.6 , 47.52, 48.44, 49.36, 50.28, 51.2 ,
#         52.12, 53.04, 53.96, 54.88, 55.8 , 56.72, 57.64, 58.56, 59.48,
#         60.4 , 61.32, 62.24, 63.16, 64.08, 65.  ]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a2bb92cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a2bb9b7d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a2bb92050>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a2bb92d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a2bba1750>],
#  'means': []}

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
df.plot.scatter(x='age', y='length_of_service', c='DarkBlue')

# %%
plt.scatter(x=df['age'], y=df['length_of_service'])

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A:
plt.hist(df['store_name'], bins=10)
# Out:
# (array([ 3403.,  3124.,  1379.,  9351.,  4495.,  2786.,  5698.,  3003.,
#          3689., 12725.]),
#  array([ 1. ,  5.5, 10. , 14.5, 19. , 23.5, 28. , 32.5, 37. , 41.5, 46. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:
print(df['age'].describe())
df.describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# ...

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
