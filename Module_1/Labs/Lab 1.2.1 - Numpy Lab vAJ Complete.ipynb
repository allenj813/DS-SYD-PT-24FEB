# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Numpy Exploration

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# get matplot to show charts inline
# %matplotlib inline

# %%
height = np.round(np.random.normal(1.75, 0.20, 7000), 2)
weight = np.round(np.random.normal(60.32, 15, 7000), 2)
population = np.column_stack([height, weight])

heightplot = plt.plot(height)
plt.show(heightplot)
weightplot = plt.plot(weight)
plt.show(weightplot)
populationplot = plt.plot(population)
plt.show(populationplot)

# %%
print('height:\n', height)
print('weight:\n', weight)
print('population:\n', population)
# Out:
# height:
#  [1.91 1.81 1.44 ... 1.94 1.81 1.81]
# weight:
#  [79.71 69.62 62.79 ... 66.94 73.6  53.  ]
# population:
#  [[ 1.91 79.71]
#  [ 1.81 69.62]
#  [ 1.44 62.79]
#  ...
#  [ 1.94 66.94]
#  [ 1.81 73.6 ]
#  [ 1.81 53.  ]]

# %% [markdown]
# **1. Find Dimension of Array**
#
# Find dimension of each array: height, weight, population
# ```
# # Expected Ouput
# np.ndim(height): 1
# np.ndim(weight): 1
# np.ndim(population): 2
# ```

# %%
print(np.ndim(height))
print(np.ndim(weight))
print(np.ndim(population))
# Out:
# 1
# 1
# 2

# %% [markdown]
# **2. Find Shape of Array**
#
# Find shape of each array: height, weight, population
# ```
# # Expected Ouput
# np.shape(height) : (7000,)
# np.shape(weight) : (7000,)
# np.shape(population) : (7000, 2)
# ```

# %%
print(np.shape(height))
print(np.shape(weight))
print(np.shape(population))
# Out:
# (7000,)
# (7000,)
# (7000, 2)

# %% [markdown]
# **3. Find Size of Array**
#
# Find shape of each array: height, weight, population
# ```
# # Expected Ouput:
# np.size(height) : 7000
# np.size(weight) : 7000
# np.size(weight) : 14000
# ```

# %%
print(np.size(height))
print(np.size(weight))
print(np.size(population))
# Out:
# 7000
# 7000
# 14000

# %% [markdown]
# **4. Find Size of Items of Each Array**
#
# Find size of items each array: height, weight, population
# ```
# # Expected Output:
# height.itemsize : 8
# weight.itemsize : 8
# population.itemsize : 8
# ```

# %%
print(height.itemsize)
print(weight.itemsize)
print(population.itemsize)
# Out:
# 8
# 8
# 8

# %% [markdown]
# **4. Find Minimum Value of Each Array**
#
# Find minimum value of each array: height, weight, population
# ```
# # Expected Output:
# height.min : 1.0
# weight.min : 3.24
# population.min : 1.0
# ```

# %%
print(height.min())
print(weight.min())
print(population.min())
# Out:
# 0.87
# 6.3
# 0.87

# %% [markdown]
# **5. Find Maximum Value of Each Array**
#
# Find maximum value of each array: height, weight, population
# ```
# # Expected Output
# height.max() : 2.51
# weight.max() : 132.17
# population.max() : 132.17
# ```

# %%
print(height.max())
print(weight.max())
print(population.max())
# Out:
# 2.49
# 117.08
# 117.08

# %% [markdown]
# **6. Find Mean Value of Each Array**
#
# Find maximum value of each array: height, weight, population
# ```
# # Expected Output
# height.mean() : 1.7494871428571428
# weight.mean() : 60.41684428571429
# population.mean() : 31.083165714285716
# ```

# %%
print(height.mean())
print(weight.mean())
print(population.mean())
# Out:
# 1.7501414285714287
# 60.63187285714285
# 31.191007142857142

# %% [markdown]
# **6. Find Standard Deviation of Each Array**
#
# Find standard deviation value of each array: height, weight, population
# ```
# # Expected Output
# height.std() : 0.1981923748970856
# weight.std() : 14.821310711612284
# population.std() : 31.090684288943482
# ```

# %%
print(height.std())
print(weight.std())
print(population.std())
# Out:
# 0.19983620435093274
# 15.302255551513792
# 31.36660730367258

# %% [markdown]
# **7. Find Total value of Each Array**
#
# Find total value of each array: height, weight, population
# ```
# # Expected Output
# height.sum() : 12219.789999999999
# weight.sum() : 422009.95
# population.sum() : 434229.74
# ```

# %%
print(height.sum())
print(weight.sum())
print(population.sum())
# Out:
# 12250.990000000002
# 424423.11
# 436674.1

# %% [markdown]
# **8. Create a histogram of height and weight**

# %%
print(plt.hist(height, bins=20))
# Out:
# (array([1.000e+00, 2.000e+00, 4.000e+00, 1.500e+01, 3.400e+01, 1.130e+02,
#        2.350e+02, 4.220e+02, 7.190e+02, 1.086e+03, 1.110e+03, 1.056e+03,
#        8.670e+02, 6.140e+02, 3.790e+02, 2.120e+02, 8.500e+01, 3.300e+01,
#        7.000e+00, 6.000e+00]), array([0.87 , 0.951, 1.032, 1.113, 1.194, 1.275, 1.356, 1.437, 1.518,
#        1.599, 1.68 , 1.761, 1.842, 1.923, 2.004, 2.085, 2.166, 2.247,
#        2.328, 2.409, 2.49 ]), <a list of 20 Patch objects>)

# %%
print(plt.hist(weight, bins=20, color='Orange'))
# Out:
# (array([  7.,  12.,  28.,  77., 160., 310., 507., 673., 923., 975., 994.,
#        862., 615., 395., 244., 127.,  60.,  21.,   5.,   5.]), array([  6.3  ,  11.839,  17.378,  22.917,  28.456,  33.995,  39.534,
#         45.073,  50.612,  56.151,  61.69 ,  67.229,  72.768,  78.307,
#         83.846,  89.385,  94.924, 100.463, 106.002, 111.541, 117.08 ]), <a list of 20 Patch objects>)

# %% [markdown]
# **9. Create a boxplot of height and weight**

# %%
plt.boxplot(x=[height, weight])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11e31ad50>,
#   <matplotlib.lines.Line2D at 0x11f615f50>,
#   <matplotlib.lines.Line2D at 0x11f622e50>,
#   <matplotlib.lines.Line2D at 0x11f61df50>],
#  'caps': [<matplotlib.lines.Line2D at 0x11f61d490>,
#   <matplotlib.lines.Line2D at 0x11f61d990>,
#   <matplotlib.lines.Line2D at 0x11f62a850>,
#   <matplotlib.lines.Line2D at 0x11f62ad50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11e31ad10>,
#   <matplotlib.lines.Line2D at 0x11f622950>],
#  'medians': [<matplotlib.lines.Line2D at 0x11f61ded0>,
#   <matplotlib.lines.Line2D at 0x11f61de90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11e306050>,
#   <matplotlib.lines.Line2D at 0x11f633790>],
#  'means': []}

# %%
plt.boxplot(height)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11e3f0dd0>,
#   <matplotlib.lines.Line2D at 0x11f6eafd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11f6f1510>,
#   <matplotlib.lines.Line2D at 0x11f6f1a10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11e3f0d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x11f6f1f50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11f6f6490>],
#  'means': []}

# %%
plt.boxplot(weight)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11ddb9ed0>,
#   <matplotlib.lines.Line2D at 0x11ddbaa10>],
#  'caps': [<matplotlib.lines.Line2D at 0x11e39a790>,
#   <matplotlib.lines.Line2D at 0x11e3ad990>],
#  'boxes': [<matplotlib.lines.Line2D at 0x11ddb9f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x11ddba9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11e381190>],
#  'means': []}

# %%
plt.boxplot?

# %% [markdown]
# **10. Create scatterplot of height and weight**

# %%
plt.scatter(height, weight)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
