# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.2
# # *Mining Social Media with Twitter*

# %% [markdown]
# ## The Twitter API and Tweepy Package

# %% [markdown]
# The Twitter API provides access to tweets and comments, and allows an application to post tweets to the user's timeline.
#
# Twitter requires developers to create and authenticate an app before they can use the API. As of recent policy changes, however, new developers must be approved before they can create an app. There is no indication of the waiting period for approval.

# %% [markdown]
# ### 1. Apply for Developer Access
#
# Go to https://blog.twitter.com/developer/en_us/topics/tools/2018/new-developer-requirements-to-protect-our-platform.html
# and read the advice.
# ![image.png](attachment:image.png)

# %% [markdown]
# Apply at https://developer.twitter.com/en/apply-for-access.html
# ![image.png](attachment:image.png)

# %% [markdown]
# Then go to https://developer.twitter.com/en/review every day until you see whatever comes after this:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Create Your Twitter App
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Load Python Libraries

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.11.1 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: PySocks>=1.5.7 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from tweepy) (1.12.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl (147kB)
#      |████████████████████████████████| 153kB 5.2MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/allenj/opt/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.1.0 requests-oauthlib-1.3.0 tweepy-3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import json
import pprint

# %% [markdown]
# ### 4. Authenticate from your Python script

# %% [markdown]
# You could assign your authentication details explicitly, as follows:

# %%
my_consumer_key = ''      # your consumer key (string) goes in here
my_consumer_secret = ''   # your consumer secret key (string) goes in here
my_access_token = ''      # your access token (string goes in here
access_token_secret = ''  # your access token secret (string) goes in here

# %% [markdown]
# A better way would be to store these details externally, so they are not displayed in the notebook:
#
# - create a file called "auth_twitter.json" in your "notebooks" directory, and save your credentials there in JSON format:
#
# `{   "my_consumer_key": "your consumer key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;` "my_consumer_secret": "your consumer secret key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"your access token (string goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"my_access_token_secret": "your access token secret (string) goes in here"` <br>
# `}`
#
# (Nb. Parsers are very fussy. Make sure each key:value pair has a comma after it except the last one!)
#
# Use the following code to load the credentials:

# %%
pwd()  # make sure your working directory is where the file is

# %%
path_auth = '/Users/allenj/Documents/Keys/auth_twitter.json'
auth = json.loads(open(path_auth).read())
pp = pprint.PrettyPrinter(indent=4)
# For debugging only:
#pp.pprint(auth)

my_consumer_key = auth['my_consumer_key']
my_consumer_secret = auth['my_consumer_secret']
my_access_token = auth['your_access_token']
my_access_token_secret = auth['my_access_token_secret']

# %% [markdown]
# Security considerations:
# - this method only keeps your credentials invisible as long as nobody accesses this notebook while it's running on your computer
# - if you wanted another user to have access to the executable notebook without divulging your credentials you should set up an OAuth 2.0 workflow to let them obtain and apply their own API tokens when using your app
# - if you just want to share your analyses, you could use a separate script (which you don't share) to fetch the data and save it locally, then use a second notebook (with no API access) to load and analyse the locally stored data

# %% [markdown]
# ### 5. Exploring the API

# %% [markdown]
# Here is how to connect to Twitter using the Tweepy library:

# %%
auth = tweepy.OAuthHandler(my_consumer_key, my_consumer_secret)
auth.set_access_token(my_access_token, my_access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# In the next cell, put the cursor after the '.' and hit the [tab] key to see the available members and methods in the response object:

# %%
followers = api.followers()
for follower in followers:
    print(follower)
# Out:
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 3068418605, 'id_str': '3068418605', 'name': 'William Wang', 'screen_name': 'thatdesignfirm', 'location': '', 'description': 'Data, Design, Development', 'url': 'https://t.co/AMHLFcQlpq', 'entities': {'url': {'urls': [{'url': 'https://t.co/AMHLFcQlpq', 'expanded_url': 'http://www.thatdesignfirm.com', 'display_url': 'thatdesignfirm.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 31, 'friends_count': 298, 'listed_count': 0, 'created_at': 'Tue Mar 03 18:45:37 +0000 2015', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 4, 'lang': None, 'status': {'created_at': 'Tue Mar 10 00:40:34 +0000 2015', 'id': 575093854275153920, 'id_str': '575093854275153920', 'text': "RT @TechCrunch: Today's Apple Event In 90 Seconds http://t.co/MSVVzZ60Ud by @kylebrussell", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TechCrunch', 'name': 'TechCrunch', 'id': 816653, 'id_str': '816653', 'indices': [3, 14]}, {'screen_name': 'kylebrussell', 'name': 'Kyle Russell', 'id': 52247685, 'id_str': '52247685', 'indices': [76, 89]}], 'urls': [{'url': 'http://t.co/MSVVzZ60Ud', 'expanded_url': 'http://tcrn.ch/1CXz0H4', 'display_url': 'tcrn.ch/1CXz0H4', 'indices': [50, 72]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Mar 10 00:40:12 +0000 2015', 'id': 575093763128733697, 'id_str': '575093763128733697', 'text': "Today's Apple Event In 90 Seconds http://t.co/MSVVzZ60Ud by @kylebrussell", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kylebrussell', 'name': 'Kyle Russell', 'id': 52247685, 'id_str': '52247685', 'indices': [60, 73]}], 'urls': [{'url': 'http://t.co/MSVVzZ60Ud', 'expanded_url': 'http://tcrn.ch/1CXz0H4', 'display_url': 'tcrn.ch/1CXz0H4', 'indices': [34, 56]}]}, 'source': '<a href="http://10up.com" rel="nofollow">10up Publish Tweet</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 73, 'favorite_count': 35, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 73, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/572838688057344000/1gu6uQrQ_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/572838688057344000/1gu6uQrQ_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3068418605/1425410866', 'profile_link_color': 'ABB8C2', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=3068418605, id_str='3068418605', name='Will ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 21363252, 'id_str': '21363252', 'name': 'William Wang', 'screen_name': 'weiwillwang', 'location': 'Seattle, CA', 'description': 'Product Designer', 'url': 'https://t.co/XEGGRSchXc', 'entities': {'url': {'urls': [{'url': 'https://t.co/XEGGRSchXc', 'expanded_url': 'http://www.wewiwa.com', 'display_url': 'wewiwa.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 56, 'friends_count': 100, 'listed_count': 1, 'created_at': 'Fri Feb 20 01:47:40 +0000 2009', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 48, 'lang': None, 'status': {'created_at': 'Fri Sep 14 19:53:27 +0000 2012', 'id': 246698192345911296, 'id_str': '246698192345911296', 'text': "@JamarrHall I'd love to talk to you about trendfilms sometime! Its a collaborative platform I'm working on.", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'JamarrHall', 'name': 'Jamarr Hall', 'id': 299976418, 'id_str': '299976418', 'indices': [0, 11]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 299976418, 'in_reply_to_user_id_str': '299976418', 'in_reply_to_screen_name': 'JamarrHall', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/572855109881589760/H50vN_th_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/572855109881589760/H50vN_th_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21363252/1549819058', 'profile_link_color': '6E9925', 'profile_sidebar_border_color': 'A8A8A8', 'profile_sidebar_fill_color': 'DEDEDE', 'profile_text_color': '454545', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=21363252, id_str='21363252', name='William Wang', screen_name='weiwillwang', location='Seattle, CA', description='Product Designer', url='https://t.co/XEGGRSchXc', entities={'url': {'urls': [{'url': 'https://t.co/XEGGRSchXc', 'expanded_url': 'http://www.wewiwa.com', 'display_url': 'wewiwa.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=56, friends_count=100, listed_count=1, created_at=datetime.datetime(2009, 2, 20, 1, 47, 40), favourites_count=1, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=48, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Fri Sep 14 19:53:27 +0000 2012', 'id': 246698192345911296, 'id_str': '246698192345911296', 'text': "@JamarrHall I'd love to talk to you about trendfilms sometime! Its a collaborative platform I'm working on.", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'JamarrHall', 'name': 'Jamarr Hall', 'id': 299976418, 'id_str': '299976418', 'indices': [0, 11]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 299976418, ' ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 3049925143, 'id_str': '3049925143', 'name': 'Victoria Smith', 'screen_name': 'bratoria89', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': True, 'followers_count': 6, 'friends_count': 131, 'listed_count': 0, 'created_at': 'Sat Feb 28 14:01:16 +0000 2015', 'favourites_count': 2, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/571671842991153153/WjvT9oya_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/571671842991153153/WjvT9oya_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3049925143/1425136903', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=3049925143, id_str='3049925143', name='Victoria Smith', screen_name='bratoria89', location='', description='', url=None, entities={'description': {'urls': []}}, protected=True, followers_count=6, friends_count=131, listed_count=0, created_at=datetime.datetime(2015, 2, 28, 14, 1, 16), favourites_count=2, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/571671842991153153/WjvT9oya_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/571671842991153153/WjvT9oya_normal.jpeg', profile_banner_url='https://pbs.twimg.com/profile_banners/3049925143/1425136903', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=False, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none')
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 14858947, 'id_str': '14858947', 'name': 'Dave Pava', 'screen_name': 'pavadavepava', 'location': 'San Francisco, CA', 'description': "Marketing consultant, meh bballer, writer, cooker & eater, and pop culture fiend. YOUTUBE/TWITCH/INSTA creators, DM me! Looking for Let's Play-ers and unboxers!", 'url': 'http://t.co/OiG2qgRuoC', 'entities': {'url': {'urls': [{'url': 'http://t.co/OiG2qgRuoC', 'expanded_url': 'http://davidpava.com', 'display_url': 'davidpava.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 659, 'friends_count': 1930, 'listed_count': 23, 'created_at': 'Wed May 21 17:13:57 +0000 2008', 'favourites_count': 942, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1027, 'lang': None, 'status': {'created_at': 'Thu Apr 16 18:56:42 +0000 2020', 'id': 1250860688211247104, 'id_str': '1250860688211247104', 'text': "Like team shooters? If yes, I could use your help! One of my clients is working on a new game and I'd be psyched if… https://t.co/Wo5hY91azj", 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Wo5hY91azj', 'expanded_url': 'https://twitter.com/i/web/status/1250860688211247104', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/560500819955433472/Z4TXsB3e_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/560500819955433472/Z4TXsB3e_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14858947/1422466222', 'profile_link_color': '336699', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=14858947, id_str='14858947', name='Dave Pava', screen_name='pavadavepava', location='San Francisco, CA', description="Marketing consultant, meh bballer, writer, cooker & eater, and pop culture fiend. YOUTUBE/TWITCH/INSTA creators, DM me! Looking for Let's Play-ers and unboxers!", url='http://t.co/OiG2qgRuoC', entities={'url': {'urls': [{'url': 'http://t.co/OiG2qgRuoC', 'expanded_url': 'http://davidpava.com', 'display_url': 'davidpava.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, protected=False, followers_count=659, friends_count=1930, listed_count=23, created_at=datetime.datetime(2008, 5, 21, 17, 13, 57), favourites_count=942, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=1027, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Thu Apr 16 18:56:42 +0000 2020', 'id': 1250860688211247104, 'id_str': '1250860688211247104', 'text': "Like team shooters? If yes, I could use your help! One of my clients is working on a new game and I'd be psyched if… https://t.co/Wo5hY91azj" ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 2950875748, 'id_str': '2950875748', 'name': 'Brick City', 'screen_name': 'BrickCityGame', 'location': 'App Store', 'description': 'Brick City: Tank Warfare - available on iPhone, iPad, and iPod', 'url': 'https://t.co/RTvwntBNlx', 'entities': {'url': {'urls': [{'url': 'https://t.co/RTvwntBNlx', 'expanded_url': 'https://itunes.apple.com/app/id584720262?mt=8', 'display_url': 'itunes.apple.com/app/id58472026…', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 13, 'friends_count': 33, 'listed_count': 0, 'created_at': 'Tue Dec 30 08:54:44 +0000 2014', 'favourites_count': 12, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 22, 'lang': None, 'status': {'created_at': 'Wed Jun 10 04:17:51 +0000 2015', 'id': 608488219877855232, 'id_str': '608488219877855232', 'text': "RT @machorneja: Battle City never gets old. Still one of the most interesting computer games ever created. Only kids from the 90's can unde…", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'machorneja', 'name': 'Mac', 'id': 29014046, 'id_str': '29014046', 'indices': [3, 14]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jun 08 13:29:12 +0000 2015', 'id': 607902196798124033, 'id_str': '607902196798124033', 'text': "Battle City never gets old. Still one of the most interesting computer games ever created. Only kids from the 90's can understand.", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/549851679621799937/vgpE2Dx-_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/549851679621799937/vgpE2Dx-_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2950875748/1420443771', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2950875748, id_str='2950875748', name='Brick City', screen_name='BrickCityGame', location='App Store', description='Brick City: Tank Warfare - available on iPhone, iPad, and iPod', url='https://t.co/RTvwntBNlx', entities={'url': {'urls': [{'url': 'https://t.co/RTvwntBNlx', 'expanded_url': 'https://itunes.apple.com/app/id584720262?mt=8', 'display_url': 'itunes.apple.com/app/id58472 ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 2922653248, 'id_str': '2922653248', 'name': 'Ian Grisedale', 'screen_name': 'eMobileWebSites', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 179, 'friends_count': 1490, 'listed_count': 4, 'created_at': 'Mon Dec 15 09:17:54 +0000 2014', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 354, 'lang': None, 'status': {'created_at': 'Sat Aug 04 18:05:17 +0000 2018', 'id': 1025804885223198720, 'id_str': '1025804885223198720', 'text': 'I liked a @YouTube video https://t.co/uCEo6mtzUg Liverpool vs Napoli live stream vivo', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'YouTube', 'name': 'YouTube', 'id': 10228272, 'id_str': '10228272', 'indices': [10, 18]}], 'urls': [{'url': 'https://t.co/uCEo6mtzUg', 'expanded_url': 'http://youtu.be/70E6ImUheV4?a', 'display_url': 'youtu.be/70E6ImUheV4?a', 'indices': [25, 48]}]}, 'source': '<a href="https://www.google.com/" rel="nofollow">Google</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/544422875147431936/4fId1MqK_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/544422875147431936/4fId1MqK_normal.jpeg', 'profile_link_color': '0099CC', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2922653248, id_str='2922653248', name='Ian Grisedale', screen_name='eMobileWebSites', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=179, friends_count=1490, listed_count=4, created_at=datetime.datetime(2014, 12, 15, 9, 17, 54), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=354, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Sat Aug 04 18:05:17 +0000 2018', 'id': 1025804885223198720, 'id_str': '1025804885223198720', 'text': 'I liked a @YouTube video https://t.co/uCEo6mtzUg Liverpool vs Napoli live stream vivo', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'YouTube', 'name': 'YouTube', 'id': 10228272, 'id_str': '10228272', 'indices': [10, 18]}], 'urls': [{'url': 'https://t.co/uCEo6mtzUg', 'expanded_url': 'http://youtu.be/70E6ImUheV4?a', 'display_url': 'youtu.be/70E6ImUheV4?a', 'indices': [25, 48]}]}, 'source': '<a href="https://www.google.com/" rel="nofollow">Google</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensi ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 515967429, 'id_str': '515967429', 'name': 'Bella Eye Care', 'screen_name': 'BellaEyeCare', 'location': 'Newark, ca ', 'description': 'For appointments: 510.494.8880\r\n6247 Jarvis Avenue \r\nNewark, CA 94560', 'url': 'http://t.co/0erUVGqYKT', 'entities': {'url': {'urls': [{'url': 'http://t.co/0erUVGqYKT', 'expanded_url': 'http://www.bella-eyecare.com', 'display_url': 'bella-eyecare.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 432, 'friends_count': 829, 'listed_count': 8, 'created_at': 'Mon Mar 05 23:18:48 +0000 2012', 'favourites_count': 119, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1543, 'lang': None, 'status': {'created_at': 'Tue Mar 17 05:49:58 +0000 2020', 'id': 1239791065881690112, 'id_str': '1239791065881690112', 'text': 'RT @juan_delcan: Do your part and stay home. It’s all we can do. https://t.co/dLOkV3znNe', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'juan_delcan', 'name': 'juan delcan & valentina izaguirre', 'id': 988824274625417216, 'id_str': '988824274625417216', 'indices': [3, 15]}], 'urls': [], 'media': [{'id': 1239353500506574850, 'id_str': '1239353500506574850', 'indices': [65, 88], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1239353500506574850/pu/img/iKpexeIY8F_DZoMs.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1239353500506574850/pu/img/iKpexeIY8F_DZoMs.jpg', 'url': 'https://t.co/dLOkV3znNe', 'display_url': 'pic.twitter.com/dLOkV3znNe', 'expanded_url': 'https://twitter.com/juan_delcan/status/1239353536028139521/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1239353536028139521, 'source_status_id_str': '1239353536028139521', 'source_user_id': 988824274625417216, 'source_user_id_str': '988824274625417216'}]}, 'extended_entities': {'media': [{'id': 1239353500506574850, 'id_str': '1239353500506574850', 'indices': [65, 88], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1239353500506574850/pu/img/iKpexeIY8F_DZoMs.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1239353500506574850/pu/img/iKpexeIY8F_DZoMs.jpg', 'url': 'https://t.co/dLOkV3znNe', 'display_url': 'pic.twitter.com/dLOkV3znNe', 'expanded_url': 'https://twitter.com/juan_delcan/status/1239353536028139521/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1239353536028139521, 'source_status_id_str': '1239353536028139521', 'source_user_id': 988824274625417216, 'source_user_id_str': '988824274625417216', 'video_info': {'aspect_ratio': [1, 1], 'duration_millis': 12075, 'variants': [{'bitrate': 1280000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1239353500506574850/pu/vid/720x720/ceWmZbsiCK4z8NKx.mp4?tag=10'}, {'bitrate': 432000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1239353500506574850/pu/vid/320x320/RI7vXZmjJUcDvCdf.mp4?tag=10'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1239353500506574850/pu/vid/480x480/sfRlBi63JeckthnZ.mp4?tag=10'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1239353500506574850/pu/pl/PO5pujLaa_2Xq-KF.m3u8?tag=10'}]}, 'additional_media_info': {'monetizable': False}}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_ ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 384721955, 'id_str': '384721955', 'name': '1776 San Francisco', 'screen_name': '1776SF', 'location': 'San Francisco, CA', 'description': "We've moved to @1776vc. Follow us there for updates.", 'url': 'https://t.co/6MWqejAA7Y', 'entities': {'url': {'urls': [{'url': 'https://t.co/6MWqejAA7Y', 'expanded_url': 'http://www.1776.vc/', 'display_url': '1776.vc', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 1268, 'friends_count': 247, 'listed_count': 97, 'created_at': 'Tue Oct 04 06:20:26 +0000 2011', 'favourites_count': 306, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 1398, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/758757474467995649/rSoalb9N_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/758757474467995649/rSoalb9N_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/384721955/1436488456', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=384721955, id_str='384721955', name='1776 San Francisco', screen_name='1776SF', location='San Francisco, CA', description="We've moved to @1776vc. Follow us there for updates.", url='https://t.co/6MWqejAA7Y', entities={'url': {'urls': [{'url': 'https://t.co/6MWqejAA7Y', 'expanded_url': 'http://www.1776.vc/', 'display_url': '1776.vc', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=True, followers_count=1268, friends_count=247, listed_count=97, created_at=datetime.datetime(2011, 10, 4, 6, 20, 26), favourites_count=306, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=1398, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='131516', profile_background_image_url='http://abs.twimg.com/images/themes/theme14/bg.gif', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme14/bg.gif', profile_background_tile=True, profile_image_url='http://pbs.twimg.com/profile_images/758757474467995649/rSoalb9N_normal.jpg', profile_image_url_https='https://pbs.twimg.com/profile_images/758757474467995649/rSoalb9N_normal.jpg', profile_banner_url='https://pbs.twimg.com/profile_banners/384721955/1436488456', profile_link_color='0084B4', profile_sidebar_border_color='FFFFFF', profile_sidebar_fill_color='EFEFEF', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=False, default_profile_image=False, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none')
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 2540091871, 'id_str': '2540091871', 'name': 'иван сединкин', 'screen_name': 'komradsedinkin', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1, 'friends_count': 11, 'listed_count': 0, 'created_at': 'Sun Jun 01 17:35:52 +0000 2014', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=2540091871, id_str='2540091871', name='иван сединкин', screen_name='komradsedinkin', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=1, friends_count=11, listed_count=0, created_at=datetime.datetime(2014, 6, 1, 17, 35, 52), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none')
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 159412015, 'id_str': '159412015', 'name': 'mario_party', 'screen_name': 'thesirmario', 'location': 'TGS | the golden state', 'description': 'life is beautiful, calm peaceful, and calamitous at the same time! so bullshit is necessary. small BS like parking tickets are necessary. deal with it? no', 'url': 'http://t.co/ZAO8SePjCP', 'entities': {'url': {'urls': [{'url': 'http://t.co/ZAO8SePjCP', 'expanded_url': 'http://www.ipostblog.com', 'display_url': 'ipostblog.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': True, 'followers_count': 98, 'friends_count': 1108, 'listed_count': 2, 'created_at': 'Fri Jun 25 08:52:03 +0000 2010', 'favourites_count': 31, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 286, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/436179633378041856/lTpn5fGb_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/436179633378041856/lTpn5fGb_normal.jpeg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/159412015/1401584448', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=159412015, id_str='159412015', name='mario_party', screen_name='thesirmario', location='TGS | the golden state', description='life is beautiful, calm peaceful, and calamitous at the same time! so bullshit is necessary. small BS like parking tickets are necessary. deal with it? no', url='http://t.co/ZAO8SePjCP', entities={'url': {'urls': [{'url': 'http://t.co/ZAO8SePjCP', 'expanded_url': 'http://www.ipostblog.com', 'display_url': 'ipostblog.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, protected=True, followers_count=98, friends_count=1108, listed_count=2, created_at=datetime.datetime(2010, 6, 25, 8, 52, 3), favourites_count=31, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=286, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://pbs.twimg.com/profile_images/436179633378041856/lTpn5fGb_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/436179633378041856/lTpn5fGb_normal.jpeg', profile_banner_url='https://pbs.twimg.com/profile_banners/159412015/1401584448', profile_link_color='0084B4', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=False, default_profile_image=False, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none')
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 229406371, 'id_str': '229406371', 'name': 'Raja Narayan, MD MPH', 'screen_name': 'rajarnarayan', 'location': 'Palo Alto, CA', 'description': 'Husband, @StanfordSurgery Resident, #AI researcher, hepatopancreatobilophile', 'url': 'https://t.co/iio5yTpjuz', 'entities': {'url': {'urls': [{'url': 'https://t.co/iio5yTpjuz', 'expanded_url': 'https://profiles.stanford.edu/Raja%20Narayan', 'display_url': 'profiles.stanford.edu/Raja%20Narayan', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 638, 'friends_count': 1191, 'listed_count': 15, 'created_at': 'Wed Dec 22 09:39:37 +0000 2010', 'favourites_count': 1042, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 996, 'lang': None, 'status': {'created_at': 'Tue May 26 23:42:31 +0000 2020', 'id': 1265428130962931713, 'id_str': '1265428130962931713', 'text': 'RT @EzraTeitelbaum: Whirling dervish common bile duct stone... seen (and retrieved) via transcystic choledochoscopy. https://t.co/Pa9WoLvVnB', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'EzraTeitelbaum', 'name': 'Ezra Teitelbaum', 'id': 1189262339092008960, 'id_str': '1189262339092008960', 'indices': [3, 18]}], 'urls': [], 'media': [{'id': 1265069160142376967, 'id_str': '1265069160142376967', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1265069160142376967/pu/img/ddogyf_8-k1yAEt1.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1265069160142376967/pu/img/ddogyf_8-k1yAEt1.jpg', 'url': 'https://t.co/Pa9WoLvVnB', 'display_url': 'pic.twitter.com/Pa9WoLvVnB', 'expanded_url': 'https://twitter.com/EzraTeitelbaum/status/1265069517073526787/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1265069517073526787, 'source_status_id_str': '1265069517073526787', 'source_user_id': 1189262339092008960, 'source_user_id_str': '1189262339092008960'}]}, 'extended_entities': {'media': [{'id': 1265069160142376967, 'id_str': '1265069160142376967', 'indices': [117, 140], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1265069160142376967/pu/img/ddogyf_8-k1yAEt1.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1265069160142376967/pu/img/ddogyf_8-k1yAEt1.jpg', 'url': 'https://t.co/Pa9WoLvVnB', 'display_url': 'pic.twitter.com/Pa9WoLvVnB', 'expanded_url': 'https://twitter.com/EzraTeitelbaum/status/1265069517073526787/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1265069517073526787, 'source_status_id_str': '1265069517073526787', 'source_user_id': 1189262339092008960, 'source_user_id_str': '1189262339092008960', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 8342, 'variants': [{'bitrate': 256000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1265069160142376967/pu/vid/480x270/43OiPSXcVwXlDmi8.mp4?tag=10'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1265069160142376967/pu/vid/1280x720/ZqIK-6VnKsSMgVqT.mp4?tag=10'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1265069160142376967/pu/vid/640x360/WeE_2m_6faMKhbpB.mp4?tag=10'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1265069160142376967/pu/pl/KGrtGpwwZJWQH2Kv.m3u8?tag=10'}]}, 'additional_media_info': {'monetizable': False}}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 32486049, 'id_str': '32486049', 'name': 'Art Chin', 'screen_name': 'artchin', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 194, 'friends_count': 324, 'listed_count': 5, 'created_at': 'Fri Apr 17 17:19:38 +0000 2009', 'favourites_count': 82, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 236, 'lang': None, 'status': {'created_at': 'Sat Apr 25 00:15:25 +0000 2020', 'id': 1253839997402140673, 'id_str': '1253839997402140673', 'text': 'Palo Alto historic resources board: SAVE THE OLD CANNERY IN PALO ALTO - Save space for local culture, bring back Ar… https://t.co/4ZAp1nvcK1', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/4ZAp1nvcK1', 'expanded_url': 'https://twitter.com/i/web/status/1253839997402140673', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '642D8B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/142794493/Arthur_Chin_smallpic_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/142794493/Arthur_Chin_smallpic_normal.jpg', 'profile_link_color': 'FF0000', 'profile_sidebar_border_color': '65B0DA', 'profile_sidebar_fill_color': '7AC3EE', 'profile_text_color': '3D1957', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=32486049, id_str='32486049', name='Art Chin', screen_name='artchin', location='', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=194, friends_count=324, listed_count=5, created_at=datetime.datetime(2009, 4, 17, 17, 19, 38), favourites_count=82, utc_offset=None, time_zone=None, geo_enabled=False, verified=False, statuses_count=236, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Sat Apr 25 00:15:25 +0000 2020', 'id': 1253839997402140673, 'id_str': '1253839997402140673', 'text': 'Palo Alto historic resources board: SAVE THE OLD CANNERY IN PALO ALTO - Save space for local culture, bring back Ar… https://t.co/4ZAp1nvcK1', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/4ZAp1nvcK1', 'expanded_url': 'https://twitter.com/i/web/status/1253839997402140673', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': ...
# ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 15203483, 'id_str': '15203483', 'name': 'dougradtke', 'screen_name': 'dougradtke', 'location': 'Mountain View, CA', 'description': 'San Francisco Bay Area - Certified Public Accountant', 'url': 'https://t.co/gOHKCPMtCH', 'entities': {'url': {'urls': [{'url': 'https://t.co/gOHKCPMtCH', 'expanded_url': 'http://www.radtkecpa.com', 'display_url': 'radtkecpa.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 213, 'friends_count': 716, 'listed_count': 7, 'created_at': 'Mon Jun 23 03:39:03 +0000 2008', 'favourites_count': 124, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 3159, 'lang': None, 'status': {'created_at': 'Tue May 19 15:22:11 +0000 2020', 'id': 1262765501404426242, 'id_str': '1262765501404426242', 'text': 'RT @EHP_Cares: Thank you to all who gave food donations to help our neighbors in need get through this most difficult of times. @EHP_Cares…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'EHP_Cares', 'name': 'ehp_cares', 'id': 2915257236, 'id_str': '2915257236', 'indices': [3, 13]}, {'screen_name': 'EHP_Cares', 'name': 'ehp_cares', 'id': 2915257236, 'id_str': '2915257236', 'indices': [128, 138]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon May 18 23:58:25 +0000 2020', 'id': 1262533030951874561, 'id_str': '1262533030951874561', 'text': 'Thank you to all who gave food donations to help our neighbors in need get through this most difficult of times.… https://t.co/llhR9vs9IU', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/llhR9vs9IU', 'expanded_url': 'https://twitter.com/i/web/status/1262533030951874561', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [114, 137]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'is_quote_status': False, 'retweet_count': 1, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '352726', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1253179982152495105/a18aBfTZ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1253179982152495105/a18aBfTZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15203483/1587616366', 'profile_link_color': 'D02B55', 'profile_sidebar_border_color': '829D5E', 'profile_sidebar_fill_color': '99CC33', 'profile_text_color': '3E4415', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=15203483, id_str='15203483', name='dougradtke', screen_name='dougradtke', location='Mountain View ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 329774977, 'id_str': '329774977', 'name': 'GaryYuen', 'screen_name': 'garyuen', 'location': 'BK', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 16, 'friends_count': 70, 'listed_count': 0, 'created_at': 'Tue Jul 05 16:11:50 +0000 2011', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 0, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': True, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=329774977, id_str='329774977', name='GaryYuen', screen_name='garyuen', location='BK', description='', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=16, friends_count=70, listed_count=0, created_at=datetime.datetime(2011, 7, 5, 16, 11, 50), favourites_count=0, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=0, lang=None, contributors_enabled=False, is_translator=False, is_translation_enabled=False, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_link_color='1DA1F2', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, has_extended_profile=False, default_profile=True, default_profile_image=True, following=False, live_following=False, follow_request_sent=False, notifications=False, muting=False, blocking=False, blocked_by=False, translator_type='none')
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 169422959, 'id_str': '169422959', 'name': 'epoissonq', 'screen_name': 'epoissonq', 'location': 'Concarneau', 'description': 'Codeveloppeur @fondsexplore @oceanisopen @KonkArLab #BretagneTransition \n@epoissonq@mamot.fr', 'url': 'https://t.co/3DvefC4knB', 'entities': {'url': {'urls': [{'url': 'https://t.co/3DvefC4knB', 'expanded_url': 'https://www.we-explore.org', 'display_url': 'we-explore.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1160, 'friends_count': 2095, 'listed_count': 89, 'created_at': 'Thu Jul 22 08:55:53 +0000 2010', 'favourites_count': 7882, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 4991, 'lang': None, 'status': {'created_at': 'Tue May 26 17:16:43 +0000 2020', 'id': 1265331042275201026, 'id_str': '1265331042275201026', 'text': '@okiewhaler @AfricanAquatic Excellent ! Do you have open documentation to inspire @KonkArLab / @FondsExplore / @AstrolabeExp / @MLozivit ?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'okiewhaler', 'name': 'Matthew S Leslie PhD (he/him/his)', 'id': 415822027, 'id_str': '415822027', 'indices': [0, 11]}, {'screen_name': 'AfricanAquatic', 'name': 'African Aquatic CF', 'id': 814106925860274176, 'id_str': '814106925860274176', 'indices': [12, 27]}, {'screen_name': 'KonkArLab', 'name': 'Konk Ar Lab', 'id': 837261632266887169, 'id_str': '837261632266887169', 'indices': [82, 92]}, {'screen_name': 'FondsExplore', 'name': 'Explore', 'id': 1446656370, 'id_str': '1446656370', 'indices': [95, 108]}, {'screen_name': 'AstrolabeExp', 'name': 'AstrolabeExpéditions', 'id': 2380346654, 'id_str': '2380346654', 'indices': [111, 124]}, {'screen_name': 'MLozivit', 'name': 'Martin Lozivit', 'id': 890110986337869825, 'id_str': '890110986337869825', 'indices': [127, 136]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1265311626946924546, 'in_reply_to_status_id_str': '1265311626946924546', 'in_reply_to_user_id': 415822027, 'in_reply_to_user_id_str': '415822027', 'in_reply_to_screen_name': 'okiewhaler', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1060913161753255937/FvhMif4D_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1060913161753255937/FvhMif4D_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/169422959/1487352929', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=169422959, id_str='169422959', name='epoissonq', screen_name='epoissonq', location='Concarneau', description='Codeveloppeur @fondsexplore @oceanisopen @KonkArLab #BretagneTransition \n@epoissonq@mamot.fr', url='https://t.co/3DvefC4knB', entities={'url': {'urls': [{'url': 'https://t.co/3DvefC4knB', 'expanded_url': 'https://www.we-explore.org', 'display_url': 'we-explore.org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_ ...
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 73789013, 'id_str': '73789013', 'name': 'Raghav Priy Karnani', 'screen_name': 'raghavkarnani', 'location': 'Kolkata, Karlsruhe', 'description': 'Ideas maketh the man. \r\nBoundaries limit the idea.\r\nMan creates the boundaries.', 'url': 'https://t.co/Pc0d4Fmmuf', 'entities': {'url': {'urls': [{'url': 'https://t.co/Pc0d4Fmmuf', 'expanded_url': 'https://www.facebook.com/awakenedindian/', 'display_url': 'facebook.com/awakenedindian/', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 61, 'friends_count': 128, 'listed_count': 1, 'created_at': 'Sun Sep 13 02:10:39 +0000 2009', 'favourites_count': 41, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 75, 'lang': None, 'status': {'created_at': 'Wed Apr 15 07:27:34 +0000 2020', 'id': 1250324873794031618, 'id_str': '1250324873794031618', 'text': 'Dear PM Modi ji, pls get a team to make short tutorials, dubbed in all national languages, that explain various mec… https://t.co/19gqAgPYMH', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/19gqAgPYMH', 'expanded_url': 'https://twitter.com/i/web/status/1250324873794031618', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/3078586077/13d53120792b159276c478ed93baa5a4_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/3078586077/13d53120792b159276c478ed93baa5a4_normal.png', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=73789013, id_str='73789013', name='Raghav Priy Karnani', screen_name='raghavkarnani', location='Kolkata, Karlsruhe', description='Ideas maketh the man. \r\nBoundaries limit the idea.\r\nMan creates the boundaries.', url='https://t.co/Pc0d4Fmmuf', entities={'url': {'urls': [{'url': 'https://t.co/Pc0d4Fmmuf', 'expanded_url': 'https://www.facebook.com/awakenedindian/', 'display_url': 'facebook.com/awakenedindian/', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=61, friends_count=128, listed_count=1, created_at=datetime.datetime(2009, 9, 13, 2, 10, 39), favourites_count=41, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=75, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Wed Apr 15 07:27:34 +0000 2020', 'id': 1250324873794031618, 'id_str': '1250324873794031618', 'text': 'Dear PM Modi ji, pls get a team to make short tutorials, dubbed in all national languages, that explain various mec… https://t.co/19gqAgPYMH', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https:/ ...

# %% [markdown]
# Consult the Tweept and Twitter API documentation. Print a few of the response members below:

# %% [markdown]
# This will fetch recent tweets from accounts you follow:

# %%
# Recent tweets from accounts you follow:
tweets = api.home_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# "It was a great day for NASA, it was a great day for @SpaceX. I think our teams worked together in a really impress… https://t.co/yM37Tqnwki
# Our @NASA_Astronauts @AstroBehnken and @Astro_Doug are safely out of @SpaceX's Crew Dragon spacecraft. https://t.co/eu91vtvPPA
# As the egress team assists @AstroBehnken and @Astro_Doug out of the capsule, we are looking at a 50% chance of favo… https://t.co/2blhGXhGVi
# Seats are rotating inside Crew Dragon in order for @AstroBehnken and @Astro_Doug to more comfortably exit the… https://t.co/HQqdsilRA8
# The egress team has successfully opened the hatch. @AstroBehnken and @Astro_Doug have a couple more steps before th… https://t.co/AlHQf5m6hy
# RT @SpaceX: Artwork by @tristaneaton flying aboard Dragon https://t.co/4ZbQhcZQvp
# Since we scrubbed the launch today, the propellant has been offloaded from the rocket, the launch escape system has… https://t.co/AOkHQOM0YQ
# In case you’re just tuning in, today’s launch was scrubbed due to weather. There were no issues with the Falcon 9 r… https://t.co/djv6kucefS
# The egress team is creating a seal between the White Room and the Crew Dragon to ensure no contaminants enter the s… https://t.co/XebiVIhNYr
# #LaunchAmerica Update:
#
#  Weather is the the one thing that we actually cannot control on our missions so unfortunat… https://t.co/BTRVK6CAsW
# .@SpaceX #CrewDragon spacecraft wasn’t able to launch today due to bad weather - but the safety of our @NASA astron… https://t.co/pV5PujfFrw
# The egress team is making their way down the crew access arm and are preparing to open the hatch to assist… https://t.co/QRw5pDh73y
# The egress team has arrived to Launch Pad 39A to assist @AstroBehnken and @Astro_Doug out of the Crew Dragon. https://t.co/SX4KOxS6w8
# Made @WWERollins very proud https://t.co/UVHih9FulK https://t.co/2aR4BwhQNm
# The propellant is offloaded, the launch escape system is disarmed and the crew access arm is back. @AstroBehnken an… https://t.co/52skI58HY0
# RT @SpaceX: Standing down from launch today due to unfavorable weather in the flight path. Our next launch opportunity is Saturday, May 30…
# RT @chescaleigh: demanding the state be reopened amidst a pandemic
# vs
# demanding justice for #GeorgeFloyd https://t.co/jZKLjUUsbc
# Batch 22 company, @GetPublicGoods, came in as #10 on @BusinessInsider's list of top 25 fastest-growing DTC brands: https://t.co/biQc1cl8qN
# Moana or Wiseman for the Warriors’ draft pick - discuss https://t.co/15CFXqxTSz
# Why an instantaneous launch window? Why do we have to wait until Saturday to attempt to launch again? Here's why: https://t.co/ejHrgnCFsu

# %% [markdown]
# The request to see your own recent tweets is similar, but uses the `user_timeline` endpoint. Try this below:

# %%
my_tweets = api.user_timeline()
for tweet in my_tweets:
    print(tweet.text)
# Out:
# Work harder.
# Life, liberty, and the pursuit of your own happiness. Happy #4thofjuly celebration!
# Few words in sports are as meaningful as "Game 7." This game is about Relentlessness. Who wants it more. What if every day was #Game7?
# No other city dresses up quite like SF. Can't wait to see all the creativity of #Bay2Breakers.
# Every day is a #playoff game, that's what I call #nodaysoff.
# I'll be donating blood. Though this may never reach Boston, I hope this will help out the world in someway. #Prayforboston
# Proper use of #bigdata #analytics http://t.co/5wuoEC0y3U
# If we find life on another planet, will we stop having wars on ours? #foodforthought
# Always do your best. #RulesOfLife
# "The significant problems we face cannot be solved at the same level of thinking we were at when we created them." - Albert Einstein
# Sometimes the hard way is the right way #SiliconValley
# RT @StanfordBiz: "The best entrepreneurs solicit advice &amp; listen, but they make their own decisions &amp; are responsible for them." ...
# There needs to be fact verifications in these #debates
# If you had 15 minutes on this stage, what would you talk about? http://t.co/RKqRXknO
# What happens when you gather an international team and lock them in a distant part of Norway for three straight days? http://t.co/m3ySVrtp
# Great place to get some work done while traveling @levkaupas http://t.co/w1aN4FuD
# Bright outlook for British entrepreneurship @MADEfestival http://t.co/DibSn386
# Here at the London tech hub. What's the biggest difference between Silicon Valley and Silicon Roundabout? Risk. http://t.co/jdVav8NK
# Sep 17 to Oct 8: SF --&gt; London --&gt; Sheffield --&gt; Amsterdam --&gt; Rome --&gt; Madrid --&gt; Paris and everywhere in between!
# Sand Hill Road says that companies should be prepared to answer the "Why." #tcdisrupt http://t.co/INB11Knf

# %% [markdown]
# Now, instead of printing the text of each tweet, print the `created_at` and `id_str` methods:

# %%
my_tweets = api.user_timeline()
for tweet in my_tweets:
    print(tweet.created_at, tweet.id_str)
# Out:
# 2013-08-19 15:56:06 369487950528012288
# 2013-07-05 18:02:26 353212288565641216
# 2013-06-21 00:01:41 347866879873908736
# 2013-05-19 16:03:41 336150173308821504
# 2013-04-26 02:28:29 327610100850253824
# 2013-04-15 23:03:15 323934572502990848
# 2013-03-29 16:59:40 317682483065942016
# 2013-03-25 04:49:42 316049227182641152
# 2013-02-21 18:35:11 304660554977517568
# 2012-11-21 20:18:27 271346859551911936
# 2012-11-06 06:48:10 265707128797417472
# 2012-10-18 06:09:19 258811982994604032
# 2012-10-17 02:15:23 258390723165036545
# 2012-10-11 21:49:15 256511806074400768
# 2012-10-05 19:10:06 254297429573246976
# 2012-09-30 10:18:39 252351745987051520
# 2012-09-21 13:55:51 249144914070355968
# 2012-09-19 20:37:47 248521288719667200
# 2012-09-13 20:28:50 246344709180637187
# 2012-09-12 20:42:42 245985808505503745

# %% [markdown]
# You can create a tweet as follows:

# %%
# create a tweet:
tweet = api.update_status('Test API tweet')

# %% [markdown]
# (Nb. Don't abuse this feature! If you try to generate a zillion tweets in a loop, Twitter will ban youur account.)

# %% [markdown]
# Tweets can be deleted by reference to their `id_str` attribute:

# %%
# delete a tweet:
status = api.destroy_status(tweet.id_str)

# %% [markdown]
# You can follow a Tweeter:

# %%
# follow:
api.create_friendship('@YouTube')
# Out:
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 10228272, 'id_str': '10228272', 'name': 'YouTube', 'screen_name': 'YouTube', 'location': 'San Bruno, CA', 'description': 'Graduate #WithMe', 'url': 'https://t.co/qkVaJFk2CG', 'entities': {'url': {'urls': [{'url': 'https://t.co/qkVaJFk2CG', 'expanded_url': 'https://www.youtube.com/', 'display_url': 'youtube.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 72419835, 'friends_count': 1111, 'listed_count': 78761, 'created_at': 'Tue Nov 13 21:43:46 +0000 2007', 'favourites_count': 3589, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 26222, 'lang': None, 'status': {'created_at': 'Wed May 27 22:09:02 +0000 2020', 'id': 1265766992901881857, 'id_str': '1265766992901881857', 'text': '@taylorcontarino thank you for being so awesome! so happy you could participate!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'taylorcontarino', 'name': 'Tay💎', 'id': 1211074879975329793, 'id_str': '1211074879975329793', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1265690824119107584, 'in_reply_to_status_id_str': '1265690824119107584', 'in_reply_to_user_id': 1211074879975329793, 'in_reply_to_user_id_str': '1211074879975329793', 'in_reply_to_screen_name': 'taylorcontarino', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'AF0000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1265685471671304195/BiOk9Z2h_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265685471671304195/BiOk9Z2h_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10228272/1590597907', 'profile_link_color': 'C9191D', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'translator_type': 'regular'}, id=10228272, id_str='10228272', name='YouTube', screen_name='YouTube', location='San Bruno, CA', description='Graduate #WithMe', url='https://t.co/qkVaJFk2CG', entities={'url': {'urls': [{'url': 'https://t.co/qkVaJFk2CG', 'expanded_url': 'https://www.youtube.com/', 'display_url': 'youtube.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=72419835, friends_count=1111, listed_count=78761, created_at=datetime.datetime(2007, 11, 13, 21, 43, 46), favourites_count=3589, utc_offset=None, time_zone=None, geo_enabled=False, verified=True, statuses_count=26222, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Wed May 27 22:09:02 +0000 2020', 'id': 1265766992901881857, 'id_str': '1265766992901881857', 'text': '@taylorcontarino thank you for being so awesome! so happy you could participate!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'taylorcontarino', 'name': 'Tay💎', 'id': 1211074879975329793, 'id_str': '1211074879975329793', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1265690824119107584, 'in_reply_to_status_id_str': '1265690824119107584', 'in_reply_to_user_id ...

# %% [markdown]
# or unfollow:

# %%
# unfollow:
api.destroy_friendship('@YouTube')
# Out:
# User(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'id': 10228272, 'id_str': '10228272', 'name': 'YouTube', 'screen_name': 'YouTube', 'location': 'San Bruno, CA', 'description': 'Graduate #WithMe', 'url': 'https://t.co/qkVaJFk2CG', 'entities': {'url': {'urls': [{'url': 'https://t.co/qkVaJFk2CG', 'expanded_url': 'https://www.youtube.com/', 'display_url': 'youtube.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 72419835, 'friends_count': 1111, 'listed_count': 78761, 'created_at': 'Tue Nov 13 21:43:46 +0000 2007', 'favourites_count': 3591, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 26222, 'lang': None, 'status': {'created_at': 'Wed May 27 22:09:02 +0000 2020', 'id': 1265766992901881857, 'id_str': '1265766992901881857', 'text': '@taylorcontarino thank you for being so awesome! so happy you could participate!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'taylorcontarino', 'name': 'Tay💎', 'id': 1211074879975329793, 'id_str': '1211074879975329793', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1265690824119107584, 'in_reply_to_status_id_str': '1265690824119107584', 'in_reply_to_user_id': 1211074879975329793, 'in_reply_to_user_id_str': '1211074879975329793', 'in_reply_to_screen_name': 'taylorcontarino', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'AF0000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1265685471671304195/BiOk9Z2h_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1265685471671304195/BiOk9Z2h_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10228272/1590597907', 'profile_link_color': 'C9191D', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'translator_type': 'regular'}, id=10228272, id_str='10228272', name='YouTube', screen_name='YouTube', location='San Bruno, CA', description='Graduate #WithMe', url='https://t.co/qkVaJFk2CG', entities={'url': {'urls': [{'url': 'https://t.co/qkVaJFk2CG', 'expanded_url': 'https://www.youtube.com/', 'display_url': 'youtube.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, protected=False, followers_count=72419835, friends_count=1111, listed_count=78761, created_at=datetime.datetime(2007, 11, 13, 21, 43, 46), favourites_count=3591, utc_offset=None, time_zone=None, geo_enabled=False, verified=True, statuses_count=26222, lang=None, status=Status(_api=<tweepy.api.API object at 0x10d86ba50>, _json={'created_at': 'Wed May 27 22:09:02 +0000 2020', 'id': 1265766992901881857, 'id_str': '1265766992901881857', 'text': '@taylorcontarino thank you for being so awesome! so happy you could participate!', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'taylorcontarino', 'name': 'Tay💎', 'id': 1211074879975329793, 'id_str': '1211074879975329793', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1265690824119107584, 'in_reply_to_status_id_str': '1265690824119107584', 'in_reply_to_user_id' ...

# %% [markdown]
# >
# >

# %% [markdown]
# >
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
